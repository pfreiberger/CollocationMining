# %%
from collections import defaultdict, Counter
from geopy.distance import vincenty
from itertools import  product, groupby, combinations
import numpy as np
import pandas as pd
from tqdm import tqdm
import os
import json
from time import time
import sys, traceback
import math
import geopy as gp

# %% [markdown]
# # Data

# %%
groups = {'hindu_temple':'religious_centers',
    'mosque':'religious_centers',
    'place_of_worship' : 'religious_centers',
    'synagogue' : 'religious_centers',
    'church' : 'religious_centers',
    'meal_delivery' : 'restaurant',
    'food' : 'restaurant',
    'meal_takeaway' : 'restaurant',
    'bank' : 'finance',
    'roofing_contractor' : 'construction_contractor',
    'electrician' : 'construction_contractor',
    'plumber' : 'construction_contractor',
    'painter' : 'construction_contractor',
    'general_contractor' : 'construction_contractor',
    'health' : 'doctor',
    'lodging' : 'hotel_and_lodging'
}

# %%
with open('chicago/amenities_list.json') as outfile:
    amenitiesOldInfo = json.load(outfile)
    
amenitiesList = [amenity['Label'] for amenity in amenitiesOldInfo]
amenitiesIndices = {v: k for k, v in zip(range(len(amenitiesList)), amenitiesList)}
amenities = amenitiesList

# %%
import os
cities = {}
for file in os.listdir('Boston/revised/data/processing_data/result/'):
    try:
        data = pd.read_csv('Boston/revised/data/processing_data/result/' + file)
        data.columns = ['latitude','longitude','intensity','type','clusterId']

        for old, new in groups.items():
            data.loc[data.type == old,'type'] = new
        filteredData = data[data.type.isin(amenitiesList)]
        filteredData['id'] = filteredData.index
        filteredData.drop('intensity', axis = 1, inplace = True)
        filteredData = filteredData.drop_duplicates(['latitude','longitude','type'])
        cities[file.split('.')[0]] = filteredData
    except Exception as e:
        print(e)

# %%
sum([len(item) for item in cities.values()])
# Out:
# 1077462

# %%
total = []
for city, data in cities.items():
    total+=[len(data)]

# %% [markdown]
# # Mining

# %%
def initializeContainers(minLat, minLng, maxLat, maxLng):
    cityCoords = []
    length = vincenty((minLat, minLng), (maxLat, minLng)).kilometers
    width = vincenty((minLat, minLng), (minLat, maxLng)).kilometers
    cellSize = 2.0
    
    lngEps = (maxLat - minLat)/length*0.05
    latEps = (maxLng - minLng)/width*0.05

    latCells = int(math.ceil(length/cellSize) + 1)
    lngCells = int(math.ceil(width/cellSize) + 1)

    latStep = (maxLat - minLat)/latCells
    lngStep = (maxLng - minLng)/lngCells

    for lat in range(latCells):
        for lng in range(lngCells):
            cityCoords.append(((minLat + lat*latStep), (minLng + lng*lngStep)))
    cityCoords = np.array(cityCoords).reshape([latCells,lngCells, 2])
    hashTable = np.zeros([latCells, lngCells, len(amenitiesList)], dtype=object)
    return cityCoords, hashTable, lngEps, latEps

# %%
def asRadians(degrees):
    return degrees * math.pi / 180


def getXYpos(relativeNullPoint, p):
    """ Calculates X and Y distances in meters.
    """
    deltaLatitude = p.latitude - relativeNullPoint.latitude
    deltaLongitude = p.longitude - relativeNullPoint.longitude
    latitudeCircumference = 40075160 * math.cos(asRadians(relativeNullPoint.latitude))
    resultX = deltaLongitude * latitudeCircumference / 360
    resultY = deltaLatitude * 40008000 / 360
    return resultX, resultY

# %%
def hashData(hashTable, data, minLat, minLng, latCells, lngCells, latStep, lngStep, latEps, lngEps):
    start = time()
    relPoint = gp.Point(minLat, minLng)
    print(relPoint)
    for index, location in data.iterrows():
        lat, lng = location.latitude, location.longitude
        currentLatId, currentLngId = int((lat-minLat)/latStep), int((lng-minLng)/lngStep)

        upperLatId, bottomLatId = int((lat+latEps-minLat)/latStep), int((lat-latEps-minLat)/latStep)
        upperLngId, bottomLngId = int((lng+lngEps-minLng)/lngStep), int((lng-lngEps-minLng)/lngStep)
        otherLatId = upperLatId if upperLatId!=currentLatId else bottomLatId if bottomLatId!=currentLatId else currentLatId
        otherLatId = min(otherLatId, latCells-1)
        otherLngId = upperLngId if upperLngId!=currentLngId else bottomLngId if bottomLngId!=currentLngId else currentLngId
        otherLngId = min(otherLngId, lngCells-1)

        for latId in set([currentLatId, otherLatId]):
            for lngId in set([currentLngId, otherLngId]):
                try:
                    x, y = getXYpos(relPoint, gp.Point(lat, lng))
                    if hashTable[latId, lngId, amenitiesIndices[location.type]]:
                        hashTable[latId, lngId, amenitiesIndices[location.type]].append((lat, lng, x, y, location.id))
                        hashTable[latId, lngId, amenitiesIndices[location.type]].sort(key = lambda x : x[0])
                    else:
                        hashTable[latId, lngId, amenitiesIndices[location.type]] = [(lat, lng, x, y, location.id)]
                except Exception as e:
                    print(e)

    print('Super fast hasing took', time()-start, 'to execute')
    return hashTable, time()-start

# %%
def minePatterns(hashTable, cellsCoords, latCells, lngCells, latStep, lngStep, lngEps):
    neighborsByAmenity = {}
    start = time()
    print(lngEps)
    for lat in range(latCells):
        for lng in range(lngCells):
            currentCell = hashTable[lat, lng]
            for amenityType in amenitiesList:
                amenityNeighbors = []
                if amenityType not in neighborsByAmenity:
                    neighborsByAmenity[amenityType] = []
                #No locations of this type
                if not currentCell[amenitiesIndices[amenityType]]:
                    continue

                cellCoords = cellsCoords[lat, lng]
                #Iterate all the objects in this cell and type
                for location in filter(lambda x: 
                                           x[0] >= cellCoords[0] 
                                       and x[0] < cellCoords[0] + latStep
                                       and x[1] >= cellCoords[1]
                                       and x[1] < cellCoords[1] + lngStep,
                                       currentCell[amenitiesIndices[amenityType]]):
#                     print(currentCell[amenitiesIndices[amenityType]])
                    locationNeighbors = []
                    for neighborAmenityType in filter(lambda x: currentCell[amenitiesIndices[x]]
                                                      and x != amenityType,
                                                      amenitiesList[amenitiesIndices[amenityType]+1:]):
                        for neighborLocation in currentCell[amenitiesIndices[neighborAmenityType]]:
                            if neighborLocation[2] -  location[2] < -50:
                                continue
                            if location[2] - neighborLocation[2] > 50:
                                break
                                
                            if dist(location, neighborLocation) <= 50:
                                locationNeighbors.append((neighborLocation[4],
                                                         neighborAmenityType))
                    if len(locationNeighbors):
                        amenityNeighbors.append(((location[4],
                                                 amenityType), locationNeighbors))
                neighborsByAmenity[amenityType].extend(amenityNeighbors)
    return time()-start, neighborsByAmenity

# %%
def dist(location, neighborLocation):
    return math.sqrt((location[2]-neighborLocation[2])**2 + (location[3]-neighborLocation[3])**2)
def dist2(location, neighborLocation):
    return math.sqrt((location[0]-neighborLocation[0])**2 + (location[1]-neighborLocation[1])**2)

# %%
def mineCityStarPatterns(cityName):
    data = cities[cityName]
    data = data.drop_duplicates(['latitude','longitude','type'])
    print(cityName)
    print(len(data))
    
    start = time()
    
    minLat, minLng, maxLat, maxLng =  data.latitude.min(), data.longitude.min(), data.latitude.max(), data.longitude.max()
    lowerLeft = minLat, minLng
    upperRight = maxLat, maxLng

    cellsCoords, hashTable, lngEps, latEps = initializeContainers(minLat, minLng, maxLat, maxLng)

    latCells, lngCells, _ = cellsCoords.shape
    latStep = (maxLat - minLat)/latCells
    lngStep = (maxLng - minLng)/lngCells

    hashTable, hasingTime = hashData(hashTable, data, minLat, minLng, latCells, lngCells, latStep, lngStep, latEps, lngEps)
    materTime, neighborsByAmenity = minePatterns(hashTable, cellsCoords, latCells, lngCells, latStep, lngStep, lngEps)
    
    neighborsByAmenity = {amenity:[(set([location[1] for location in instance[1]]), instance)
                                    for instance in neighborsByAmenity[amenity]]
                                    for amenity in amenities}
    
    print('Mining algorithm took', time() - start, 'to execute')
    return cityName, len(data), neighborsByAmenity, time() - start

# %%
neighborsByAmenity['cafe']
# Out:
# []

# %%
city, dataLen, neighborsByAmenity, materTime = mineCityStarPatterns('Providence')

amenitiesCounts = defaultdict(lambda: 0)
for amenity in amenities:
    amenitiesCounts[amenity] = len(data[data.type == amenity])
# Out:
# Providence
# 8104
# 41 46m 20.0172s N, 71 28m 23.8652s W
# index 6 is out of bounds for axis 1 with size 6
# index 6 is out of bounds for axis 0 with size 6
# Super fast hasing took 1.3940939903259277 to execute
# 0.000450167648435
# Mining algorithm took 2.704102039337158 to execute

# %%
th = 0.05

def generateCandidates(colocations, amenities, patternsPrevs, k0):
    candidates = []
    for colocation in tqdm(colocations):
        for amenity in amenities[amenitiesIndex[colocation.split('.')[-1]] + 1:]:
            notPrevalent = False
            for subPattern in combinations(colocation.split('.') + [amenity], k0):
                subP = '.'.join(subPattern)
                if not subP in colocations:
                    notPrevalent = True
                    break
                if k0 > 1:
                    if patternsPrevs[k0][subP] < th:
                        notPrevalent = True
                        break
            if notPrevalent:
                continue
            candidates.append(colocation + '.' +amenity)
    return candidates

def genSecondPatterns(colocationSplit, instances):
    cliqueInstanes = []
    neighborType = colocationSplit[1]
    for starInstance in instances:
        center = starInstance[0]
        for location in starInstance[1]:
            if location[1] == neighborType:
                cliqueInstanes.append((center[0], location[0]))
    return cliqueInstanes

def genMorePatterns(colocationSplit, instances, patternsInstances):
    cliqueInstances = []
    for instance in instances:
        center = tuple([instance[0][0]])
        neighbors = instance[1]
        potentialStarNeighbors = [location for location in neighbors
                                  if location[1] in colocationSplit[1:]]
        grouping = [[location[0] for location in group]
                    for key, group in groupby(potentialStarNeighbors, lambda x: x[1])]
        referenceStars = patternsInstances[k-1]['.'.join(colocationSplit[1:])]
        cliqueInstances.extend([(center) + star for star in product(*grouping) if star in referenceStars])
    return cliqueInstances

def checkStar(instanceTypes, colocation):
    for amenity in colocation[1:]:
        if not amenity in instanceTypes:
            return False
    return True

def calculcatePatternPrevalence(colocationSplit, instances, amenitiesCounts):
    patternInstanceCounts = {}
    for instance in instances:
        for instanceID, instanceType in zip(instance, colocationSplit):
            patternInstanceCounts[(instanceID, instanceType)] = 1
    counts = Counter([amenity for (id, amenity), one in patternInstanceCounts.items()])
    ratios = [float(count)/amenitiesCounts[type] for type, count in counts.items()]
    return min(ratios)

# %%
city, dataLen, neighborsByAmenity, materTime = mineCityStarPatterns('Providence')
amenitiesCounts = defaultdict(lambda: 0)
for amenity in amenities:
    amenitiesCounts[amenity] = len(data[data.type == amenity])

start = time()
patterns = {1: [amenity for amenity in amenities]}
patternsInstances = {}
patternsPrevs = {1: {amenity:1 for amenity in amenities}}

k = 2
while len(patterns[k-1]):

    print('Length:', k)
    print('Generating')
    candidates = generateCandidates(patterns[k-1], amenities, patternsPrevs, k-1)
    if not len(candidates):
        break
    print('Candiates: ', len(candidates))
    starInstances = {}
    print('Getting Stars')
    for colocation in tqdm(candidates):
        colocationSplit = colocation.split('.')
        starInstances[colocation] = (colocationSplit, [instance for types, instance in neighborsByAmenity[colocationSplit[0]]
                                               if checkStar(types, colocationSplit)])

    cliques = {}
    patternsInstances[k] = {}
    patternsPrevs[k] = {}
    print('Checking Stars')
    for colocation, (colocationSplit, instances) in tqdm(starInstances.items()):
        if len(instances):
            if k == 2:
                cliqueInstances = genSecondPatterns(colocationSplit, instances)
                patternPrev = calculcatePatternPrevalence(colocationSplit, cliqueInstances, amenitiesCounts)
                patternsPrevs[k][colocation] = patternPrev
                if patternPrev >= th:
                    patternsInstances[k][colocation] = cliqueInstances

            else:
                cliqueInstances = genMorePatterns(colocationSplit, instances, patternsInstances)
                if len(cliqueInstances):
                    patternPrev = calculcatePatternPrevalence(colocationSplit, cliqueInstances, amenitiesCounts)
                    patternsPrevs[k][colocation] = patternPrev
                    if patternPrev >= th:
                        patternsInstances[k][colocation] = cliqueInstances
    patterns[k] = {clique:len(instances) for clique, instances in patternsInstances[k].items()}
    print('Patterns: ', len(patterns[k]))
    print('')
    k += 1

miningTime = time()-start
print('Mining algorithm took',miningTime , 'to execute')
# Out:
# Providence
# 8104
# 41 46m 20.0172s N, 71 28m 23.8652s W
# index 6 is out of bounds for axis 1 with size 6
# index 6 is out of bounds for axis 0 with size 6
# Super fast hasing took 1.4431068897247314 to execute
# 0.000450167648435
# Mining algorithm took 2.7834110260009766 to execute
# Length: 2
# Generating
# 100%|██████████| 74/74 [00:00<00:00, 10095.25it/s]
# Candiates:  2701
# Getting Stars
# 100%|██████████| 2701/2701 [00:00<00:00, 23732.97it/s]
# Checking Stars
# 100%|██████████| 2701/2701 [00:00<00:00, 43641.18it/s]
# Patterns:  292
#
# Length: 3
# Generating
# 100%|██████████| 292/292 [00:00<00:00, 17009.29it/s]
# Candiates:  704
# Getting Stars
# 100%|██████████| 704/704 [00:00<00:00, 11426.54it/s]
# Checking Stars
# 100%|██████████| 704/704 [00:00<00:00, 2647.77it/s]
# Patterns:  56
#
# Length: 4
# Generating
# 100%|██████████| 56/56 [00:00<00:00, 19211.60it/s]
# Candiates:  10
# Getting Stars
# 100%|██████████| 10/10 [00:00<00:00, 8111.20it/s]
# Checking Stars
# 100%|██████████| 10/10 [00:00<00:00, 264.51it/s]
# Patterns:  5
#
# Length: 5
# Generating
# 100%|██████████| 5/5 [00:00<00:00, 17549.39it/s]
# Mining algorithm took 0.6224308013916016 to execute

# %%
data.apply(lambda x: getXYpos(relPoint, gp.Point(x.latitude, x.longitude)[0], axis = 1))

# %%
res = mineCityStarPatternsNaive('Providence')

# %%
def mineCityStarPatternsNaive(cityName):
    data = cities[cityName]
    data = data.drop_duplicates(['latitude','longitude','type'])
    print(cityName)
    print(len(data))
    
    minLat, minLng, maxLat, maxLng =  data.latitude.min(), data.longitude.min(), data.latitude.max(), data.longitude.max()
    cellsCoords, hashTable, lngEps, latEps = initializeContainers(minLat, minLng, maxLat, maxLng)
    relPoint = gp.Point(minLat, minLng)
    data['x'] = data.apply(lambda x: getXYpos(relPoint, gp.Point(x.latitude, x.longitude))[0], axis = 1)
    data['y'] = data.apply(lambda x: getXYpos(relPoint, gp.Point(x.latitude, x.longitude))[1], axis = 1)
    start = time()
    sortedAmenities = {}
    for amenityType, locations in data.groupby('type'):
        sortedAmenities[amenityType] = list(zip(locations.x.tolist(),
                                                locations.y.tolist(),
                                               locations.type.tolist()))
        sortedAmenities[amenityType].sort(key = lambda x : x[0])

    amenityLocations = [(key, value) for (key, value) in sortedAmenities.items()]
    amenityLocations.sort(key = lambda x: x[0])
    print('Sorting took', time()-start, 'to execute')

    neighborsByAmenity = {}
    start = time()
    for amenityTypeId, (amenityType, locations) in enumerate(amenityLocations):
        print(amenityTypeId, amenityType)
        amenityNeighbors = []
        for location in locations:
            locationNeighbors = []
            for (nextAmenityType, nextLocations) in amenityLocations[amenityTypeId+1:]:
                for neighborLocation in nextLocations:
                    if neighborLocation[0] -  location[0] < -50:
                        continue
                    if location[0] - neighborLocation[0] > 50:
                        break
                    if dist2(location, neighborLocation) <= 50:
                        locationNeighbors.append(neighborLocation)
            amenityNeighbors.append((location, locationNeighbors))
        neighborsByAmenity[amenityType] = amenityNeighbors
    print(time()-start, 'to execute')
    
    print('Mining algorithm took', time() - start, 'to execute')
    return cityName, len(data), neighborsByAmenity, time() - start

# %%
parsedCities = [(cityResult[0], cityResult[2]) for cityResult in resultsHuge]

# %%
parsedCities
# Out:
# [('San_Jose', 97.30674004554749),
#  ('Birmingham', 37.33728098869324),
#  ('Pittsburgh', 61.98917102813721),
#  ('Washington', 113.27261400222778),
#  ('Milwaukee', 55.38756799697876),
#  ('San_Francisco', 204.99248504638672),
#  ('Orlando', 65.90241193771362),
#  ('Boston', 145.76894807815552),
#  ('Portland', 174.08488607406616),
#  ('Richmond', 30.8624210357666),
#  ('Nashville', 75.48789095878601),
#  ('Miami', 83.93346881866455),
#  ('Austin', 104.4635260105133),
#  ('Cincinnati', 48.10244083404541),
#  ('Columbus', 72.25601005554199),
#  ('Cleveland', 50.01270008087158),
#  ('Detroit', 62.98502993583679),
#  ('Lousville', 54.89523410797119),
#  ('Memphis', 49.70860695838928),
#  ('Oklahoma', 52.0308141708374),
#  ('Riverside', 26.514925956726074),
#  ('Buffalo', 20.34398102760315),
#  ('San_Diego', 269.6417911052704),
#  ('Jacksonville', 43.054044008255005),
#  ('Baltimore', 85.42698097229004),
#  ('Providence', 31.82670021057129),
#  ('Chicago', 340.353355884552),
#  ('Las_Vegas', 111.03325605392456),
#  ('Dallas', 170.3950479030609),
#  ('Philadelphia', 226.9371418952942),
#  ('New_Orleans', 62.90603995323181),
#  ('Phoenix', 124.24688792228699),
#  ('Raleigh', 39.34567308425903),
#  ('Indianapolis', 48.94856595993042),
#  ('Charlotte', 56.729904890060425),
#  ('Sacramento', 67.68804502487183),
#  ('St_Louis', 24.553786993026733)]

# %%
allResultsFast = []
for city, mTime in parsedCities:
    res = mineCityStarPatterns(city)
    allResultsFast.append(res)
# Out:
# San_Jose
# 35011
# 37 7m 27.4613s N, 122 2m 46.3477s W
# index 21 is out of bounds for axis 1 with size 21
# index 21 is out of bounds for axis 0 with size 21
# index 21 is out of bounds for axis 0 with size 21
# Super fast hasing took 5.808730125427246 to execute
# 0.000450518612304
# Mining algorithm took 10.000575065612793 to execute
# Birmingham
# 18703
# 33 23m 0.73824s N, 87 6m 9.9216s W
# index 26 is out of bounds for axis 1 with size 26
# index 18 is out of bounds for axis 0 with size 18
# Super fast hasing took 3.2466790676116943 to execute
# 0.000450800036018
# Mining algorithm took 5.065000057220459 to execute
# Pittsburgh
# 17892
# 40 21m 39.3793s N, 80 5m 45.9888s W
# index 11 is out of bounds for axis 1 with size 11
# index 9 is out of bounds for axis 0 with size 9
# Super fast hasing took 3.151474952697754 to execute
# 0.00045027629692
# Mining algorithm took 5.85562801361084 to execute
# Washington
# 24480
# 38 47m 30.4004s N, 77 7m 12.8039s W
# index 13 is out of bounds for axis 0 with size 13
# Super fast hasing took 4.196292877197266 to execute
# 0.000450395842395
# Mining algorithm took 8.902018070220947 to execute
# Milwaukee
# 22798
# 42 55m 14.0412s N, 88 4m 18.0124s W
# index 10 is out of bounds for axis 1 with size 10
# index 16 is out of bounds for axis 0 with size 16
# index 16 is out of bounds for axis 0 with size 16
# Super fast hasing took 4.0542120933532715 to execute
# 0.000450070054125
# Mining algorithm took 6.490677833557129 to execute
# San_Francisco
# 19791
# 37 42m 11.2741s N, 122 30m 26.4186s W
# index 7 is out of bounds for axis 0 with size 7
# index 7 is out of bounds for axis 1 with size 7
# Super fast hasing took 3.5480151176452637 to execute
# 0.00045048337929
# Mining algorithm took 11.677345037460327 to execute
# Orlando
# 27383
# 28 20m 55.0471s N, 81 30m 28.1376s W
# index 16 is out of bounds for axis 0 with size 16
# index 15 is out of bounds for axis 1 with size 15
# Super fast hasing took 4.565896034240723 to execute
# 0.000451152508315
# Mining algorithm took 7.576823949813843 to execute
# Boston
# 22979
# 42 13m 38.2717s N, 71 11m 31.506s W
# index 13 is out of bounds for axis 1 with size 13
# index 11 is out of bounds for axis 0 with size 11
# Super fast hasing took 4.008068799972534 to execute
# 0.000450128585872
# Mining algorithm took 9.950506210327148 to execute
# Portland
# 36665
# 45 25m 54.899s N, 122 50m 14.4996s W
# index 14 is out of bounds for axis 0 with size 14
# index 16 is out of bounds for axis 1 with size 16
# index 16 is out of bounds for axis 1 with size 16
# Super fast hasing took 6.357161045074463 to execute
# 0.000449873407514
# Mining algorithm took 12.223783016204834 to execute
# Richmond
# 11164
# 37 26m 46.8121s N, 77 36m 5.2272s W
# index 10 is out of bounds for axis 0 with size 10
# index 11 is out of bounds for axis 1 with size 11
# Super fast hasing took 1.8959529399871826 to execute
# 0.000450501177388
# Mining algorithm took 3.2116501331329346 to execute
# Nashville
# 25389
# 35 58m 2.3412s N, 87 3m 20.0736s W
# index 26 is out of bounds for axis 0 with size 26
# index 26 is out of bounds for axis 1 with size 26
# Super fast hasing took 4.295361042022705 to execute
# 0.000450602989436
# Mining algorithm took 7.270764112472534 to execute
# Miami
# 20246
# 25 42m 31.6962s N, 80 19m 12.0216s W
# index 10 is out of bounds for axis 1 with size 10
# index 10 is out of bounds for axis 0 with size 10
# Super fast hasing took 3.419283151626587 to execute
# 0.000451325989638
# Mining algorithm took 7.01097297668457 to execute
# Austin
# 35614
# 30 5m 57.0854s N, 97 56m 19.3643s W
# index 19 is out of bounds for axis 1 with size 19
# index 25 is out of bounds for axis 0 with size 25
# Super fast hasing took 6.03750205039978 to execute
# 0.000451028808608
# Mining algorithm took 10.706816911697388 to execute
# Cincinnati
# 18352
# 39 3m 4.84524s N, 84 42m 32.1278s W
# index 11 is out of bounds for axis 0 with size 11
# index 16 is out of bounds for axis 1 with size 16
# Super fast hasing took 3.0506510734558105 to execute
# 0.000450377069382
# Mining algorithm took 5.15773606300354 to execute
# Columbus
# 33558
# 39 48m 28.0847s N, 83 12m 33.1549s W
# index 21 is out of bounds for axis 0 with size 21
# index 20 is out of bounds for axis 1 with size 20
# Super fast hasing took 5.6925129890441895 to execute
# 0.000450311251582
# Mining algorithm took 8.816073894500732 to execute
# Cleveland
# 20541
# 41 23m 25.8392s N, 81 52m 45.4548s W
# index 13 is out of bounds for axis 0 with size 13
# index 16 is out of bounds for axis 1 with size 16
# index 16 is out of bounds for axis 1 with size 16
# Super fast hasing took 3.4701499938964844 to execute
# 0.000450192980428
# Mining algorithm took 5.354231834411621 to execute
# Detroit
# 30249
# 42 15m 16.6392s N, 83 17m 19.9104s W
# index 17 is out of bounds for axis 1 with size 17
# index 12 is out of bounds for axis 0 with size 12
# Super fast hasing took 5.077351808547974 to execute
# 0.000450125482982
# Mining algorithm took 7.49091100692749 to execute
# Lousville
# 25853
# 37 59m 49.4196s N, 85 56m 53.6831s W
# index 25 is out of bounds for axis 1 with size 25
# index 23 is out of bounds for axis 0 with size 23
# Super fast hasing took 4.245122909545898 to execute
# 0.000450450329082
# Mining algorithm took 6.5332419872283936 to execute
# Memphis
# 24493
# 34 59m 52.7813s N, 90 17m 36.0046s W
# index 16 is out of bounds for axis 0 with size 16
# index 31 is out of bounds for axis 1 with size 31
# Super fast hasing took 4.089034080505371 to execute
# 0.000450682064549
# Mining algorithm took 6.066538095474243 to execute
# Oklahoma
# 25500
# 35 17m 24.5458s N, 97 49m 2.3106s W
# index 23 is out of bounds for axis 0 with size 23
# index 31 is out of bounds for axis 1 with size 31
# Super fast hasing took 4.2256059646606445 to execute
# 0.000450655837762
# Mining algorithm took 6.198739051818848 to execute
# Riverside
# 9803
# 33 52m 20.455s N, 117 31m 28.9718s W
# index 13 is out of bounds for axis 1 with size 13
# index 10 is out of bounds for axis 0 with size 10
# Super fast hasing took 1.6985368728637695 to execute
# 0.000450769618876
# Mining algorithm took 2.6705918312072754 to execute
# Buffalo
# 8106
# 42 49m 33.1817s N, 78 54m 33.7759s W
# index 6 is out of bounds for axis 1 with size 6
# index 9 is out of bounds for axis 0 with size 9
# Super fast hasing took 1.3600969314575195 to execute
# 0.000450082600676
# Mining algorithm took 2.1993491649627686 to execute
# San_Diego
# 65261
# 32 32m 3.4962s N, 117 16m 56.226s W
# index 34 is out of bounds for axis 0 with size 34
# index 19 is out of bounds for axis 1 with size 19
# Super fast hasing took 11.022140979766846 to execute
# 0.000450851168966
# Mining algorithm took 21.5690279006958 to execute
# Jacksonville
# 27106
# 30 6m 9.96624s N, 82 2m 21.3612s W
# index 33 is out of bounds for axis 1 with size 33
# Super fast hasing took 4.546303987503052 to execute
# 0.000451026556702
# Mining algorithm took 6.708314895629883 to execute
# Baltimore
# 18458
# 39 11m 47.6171s N, 76 42m 42.0246s W
# index 9 is out of bounds for axis 1 with size 9
# index 11 is out of bounds for axis 0 with size 11
# Super fast hasing took 3.16758394241333 to execute
# 0.00045036557358
# Mining algorithm took 6.334074020385742 to execute
# Providence
# 8104
# 41 46m 20.0172s N, 71 28m 23.8652s W
# index 6 is out of bounds for axis 1 with size 6
# index 6 is out of bounds for axis 0 with size 6
# Super fast hasing took 1.4112119674682617 to execute
# 0.000450167648435
# Mining algorithm took 2.7620389461517334 to execute
# Chicago
# 65601
# 41 38m 37.0968s N, 87 56m 27.7444s W
# index 19 is out of bounds for axis 1 with size 19
# index 23 is out of bounds for axis 0 with size 23
# index 23 is out of bounds for axis 0 with size 23
# Super fast hasing took 11.383198976516724 to execute
# 0.000450166347419
# Mining algorithm took 24.099882125854492 to execute
# Las_Vegas
# 43737
# 35 57m 52.3087s N, 115 21m 6.59304s W
# index 20 is out of bounds for axis 1 with size 20
# index 20 is out of bounds for axis 1 with size 20
# index 20 is out of bounds for axis 0 with size 20
# Super fast hasing took 7.278950929641724 to execute
# 0.000450606922043
# Mining algorithm took 12.1024649143219 to execute
# Dallas
# 68366
# 32 37m 2.70804s N, 96 59m 59.0892s W
# index 27 is out of bounds for axis 1 with size 27
# index 24 is out of bounds for axis 0 with size 24
# Super fast hasing took 11.444823026657104 to execute
# 0.000450851432021
# Mining algorithm took 18.8192241191864 to execute
# Philadelphia
# 46477
# 39 51m 58.3992s N, 75 16m 50.8253s W
# index 15 is out of bounds for axis 1 with size 15
# index 17 is out of bounds for axis 0 with size 17
# Super fast hasing took 7.756387948989868 to execute
# 0.000450309754378
# Mining algorithm took 16.229795932769775 to execute
# New_Orleans
# 17274
# 29 52m 2.3916s N, 90 8m 19.1846s W
# index 14 is out of bounds for axis 0 with size 14
# index 14 is out of bounds for axis 0 with size 14
# index 14 is out of bounds for axis 0 with size 14
# index 14 is out of bounds for axis 0 with size 14
# index 14 is out of bounds for axis 1 with size 14
# index 14 is out of bounds for axis 1 with size 14
# Super fast hasing took 2.9601409435272217 to execute
# 0.000451051128629
# Mining algorithm took 5.75977087020874 to execute
# Phoenix
# 54999
# 33 17m 27.2749s N, 112 19m 31.9235s W
# index 34 is out of bounds for axis 0 with size 34
# index 20 is out of bounds for axis 1 with size 20
# Super fast hasing took 9.330006837844849 to execute
# 0.000450796112895
# Mining algorithm took 14.905254125595093 to execute
# Raleigh
# 19373
# 35 42m 55.2852s N, 78 49m 10.0452s W
# index 17 is out of bounds for axis 1 with size 17
# index 15 is out of bounds for axis 0 with size 15
# Super fast hasing took 3.2659058570861816 to execute
# 0.000450628927367
# Mining algorithm took 5.031283855438232 to execute
# Indianapolis
# 24214
# 39 37m 52.2084s N, 86 19m 42.3008s W
# index 18 is out of bounds for axis 1 with size 18
# index 18 is out of bounds for axis 1 with size 18
# index 18 is out of bounds for axis 0 with size 18
# Super fast hasing took 4.082376003265381 to execute
# 0.000450327124516
# Mining algorithm took 5.947571039199829 to execute
# Charlotte
# 26410
# 35 1m 15.5266s N, 81 0m 32.2488s W
# index 22 is out of bounds for axis 0 with size 22
# index 17 is out of bounds for axis 1 with size 17
# Super fast hasing took 4.411355018615723 to execute
# 0.000450676319966
# Mining algorithm took 6.995920896530151 to execute
# Sacramento
# 22987
# 38 26m 14.532s N, 121 33m 35.7664s W
# index 15 is out of bounds for axis 0 with size 15
# index 12 is out of bounds for axis 1 with size 12
# Super fast hasing took 3.917733907699585 to execute
# 0.000450421514442
# Mining algorithm took 6.870434999465942 to execute
# St_Louis
# 13610
# 38 31m 56.7012s N, 90 19m 16.6404s W
# index 8 is out of bounds for axis 1 with size 8
# index 15 is out of bounds for axis 0 with size 15
# Super fast hasing took 2.2771220207214355 to execute
# 0.000450414407892
# Mining algorithm took 3.5283098220825195 to execute

# %%
allResultsNaive = []
for city, mTime in parsedCities:
    if mTime < 200:
        res = mineCityStarPatternsNaive(city)
        allResultsNaive.append(res)
# Out:
# San_Jose
# 35011
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Sorting took 0.06441402435302734 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 73 zoo
# 601.1406629085541 to execute
# Mining algorithm took 601.1421010494232 to execute
# Birmingham
# 18703
# Sorting took 0.039045095443725586 to execute
# 0 accounting
# 1 airport
# 2 aquarium
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 cemetery
# 18 city_hall
# 19 clothing_store
# 20 construction_contractor
# 21 convenience_store
# 22 courthouse
# 23 dentist
# 24 department_store
# 25 doctor
# 26 electronics_store
# 27 embassy
# 28 finance
# 29 fire_station
# 30 florist
# 31 funeral_home
# 32 furniture_store
# 33 gas_station
# 34 grocery_or_supermarket
# 35 gym
# 36 hardware_store
# 37 home_goods_store
# 38 hospital
# 39 hotel_and_lodging
# 40 insurance_agency
# 41 jewelry_store
# 42 laundry
# 43 lawyer
# 44 library
# 45 liquor_store
# 46 local_government_office
# 47 locksmith
# 48 movie_theater
# 49 moving_company
# 50 museum
# 51 night_club
# 52 park
# 53 parking
# 54 pet_store
# 55 pharmacy
# 56 physiotherapist
# 57 police
# 58 post_office
# 59 real_estate_agency
# 60 religious_centers
# 61 restaurant
# 62 school
# 63 shoe_store
# 64 spa
# 65 stadium
# 66 storage
# 67 train_station
# 68 travel_agency
# 69 university
# 70 veterinary_care
# 168.75925397872925 to execute
# Mining algorithm took 168.76056003570557 to execute
# Pittsburgh
# 17892
# Sorting took 0.03839397430419922 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 147.66173911094666 to execute
# Mining algorithm took 147.66321301460266 to execute
# Washington
# 24480
# Sorting took 0.04086899757385254 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 289.314120054245 to execute
# Mining algorithm took 289.3156909942627 to execute
# Milwaukee
# 22798
# Sorting took 0.04378700256347656 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 253.15464115142822 to execute
# Mining algorithm took 253.15612316131592 to execute
# Orlando
# 27383
# Sorting took 0.04840803146362305 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 358.95222878456116 to execute
# Mining algorithm took 358.95396995544434 to execute
# Boston
# 22979
# Sorting took 0.04478096961975098 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 252.70674395561218 to execute
# Mining algorithm took 252.70818400382996 to execute
# Portland
# 36665
# Sorting took 0.053182125091552734 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 622.6601588726044 to execute
# Mining algorithm took 622.6615979671478 to execute
# Richmond
# 11164
# Sorting took 0.03489804267883301 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 finance
# 29 fire_station
# 30 florist
# 31 funeral_home
# 32 furniture_store
# 33 gas_station
# 34 grocery_or_supermarket
# 35 gym
# 36 hardware_store
# 37 home_goods_store
# 38 hospital
# 39 hotel_and_lodging
# 40 insurance_agency
# 41 jewelry_store
# 42 laundry
# 43 lawyer
# 44 library
# 45 liquor_store
# 46 local_government_office
# 47 locksmith
# 48 movie_theater
# 49 moving_company
# 50 museum
# 51 night_club
# 52 park
# 53 parking
# 54 pet_store
# 55 pharmacy
# 56 physiotherapist
# 57 police
# 58 post_office
# 59 real_estate_agency
# 60 religious_centers
# 61 restaurant
# 62 school
# 63 shoe_store
# 64 spa
# 65 stadium
# 66 storage
# 67 train_station
# 68 travel_agency
# 69 university
# 70 veterinary_care
# 59.36695194244385 to execute
# Mining algorithm took 59.368366956710815 to execute
# Nashville
# 25389
# Sorting took 0.050124168395996094 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 73 zoo
# 309.7504651546478 to execute
# Mining algorithm took 309.7519381046295 to execute
# Miami
# 20246
# Sorting took 0.04176497459411621 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 203.70250606536865 to execute
# Mining algorithm took 203.70385193824768 to execute
# Austin
# 35614
# Sorting took 0.05053520202636719 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 632.2179620265961 to execute
# Mining algorithm took 632.2191691398621 to execute
# Cincinnati
# 18352
# Sorting took 0.038340091705322266 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 73 zoo
# 171.79002904891968 to execute
# Mining algorithm took 171.79173612594604 to execute
# Columbus
# 33558
# Sorting took 0.05553698539733887 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 561.0149171352386 to execute
# Mining algorithm took 561.017138004303 to execute
# Cleveland
# 20541
# Sorting took 0.04010200500488281 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 203.0781810283661 to execute
# Mining algorithm took 203.07971000671387 to execute
# Detroit
# 30249
# Sorting took 0.05000710487365723 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 440.3680760860443 to execute
# Mining algorithm took 440.3696069717407 to execute
# Lousville
# 25853
# Sorting took 0.04453015327453613 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 travel_agency
# 69 university
# 70 veterinary_care
# 71 zoo
# 326.82460284233093 to execute
# Mining algorithm took 326.8259279727936 to execute
# Memphis
# 24493
# Sorting took 0.04010200500488281 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 290.9514811038971 to execute
# Mining algorithm took 290.95284700393677 to execute
# Oklahoma
# 25500
# Sorting took 0.04223513603210449 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 308.793585062027 to execute
# Mining algorithm took 308.7950191497803 to execute
# Riverside
# 9803
# Sorting took 0.034211158752441406 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 city_hall
# 19 clothing_store
# 20 construction_contractor
# 21 convenience_store
# 22 courthouse
# 23 dentist
# 24 department_store
# 25 doctor
# 26 electronics_store
# 27 finance
# 28 fire_station
# 29 florist
# 30 funeral_home
# 31 furniture_store
# 32 gas_station
# 33 grocery_or_supermarket
# 34 gym
# 35 hardware_store
# 36 home_goods_store
# 37 hospital
# 38 hotel_and_lodging
# 39 insurance_agency
# 40 jewelry_store
# 41 laundry
# 42 lawyer
# 43 library
# 44 liquor_store
# 45 local_government_office
# 46 locksmith
# 47 movie_theater
# 48 moving_company
# 49 museum
# 50 night_club
# 51 park
# 52 parking
# 53 pet_store
# 54 pharmacy
# 55 physiotherapist
# 56 police
# 57 post_office
# 58 real_estate_agency
# 59 religious_centers
# 60 restaurant
# 61 school
# 62 shoe_store
# 63 spa
# 64 storage
# 65 train_station
# 66 travel_agency
# 67 university
# 68 veterinary_care
# 47.77390193939209 to execute
# Mining algorithm took 47.7765839099884 to execute
# Buffalo
# 8106
# Sorting took 0.02974700927734375 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 30.60790491104126 to execute
# Mining algorithm took 30.61003589630127 to execute
# Jacksonville
# 27106
# Sorting took 0.04922890663146973 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 353.4680769443512 to execute
# Mining algorithm took 353.46980595588684 to execute
# Baltimore
# 18458
# Sorting took 0.037918806076049805 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 164.8273220062256 to execute
# Mining algorithm took 164.82904314994812 to execute
# Providence
# 8104
# Sorting took 0.03157687187194824 to execute
# 0 accounting
# 1 airport
# 2 aquarium
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 storage
# 67 train_station
# 68 travel_agency
# 69 university
# 70 veterinary_care
# 32.867897033691406 to execute
# Mining algorithm took 32.872472047805786 to execute
# Las_Vegas
# 43737
# Sorting took 0.0587010383605957 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 912.0127499103546 to execute
# Mining algorithm took 912.0140600204468 to execute
# Dallas
# 68366
# Sorting took 0.0831441879272461 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 73 zoo
# 2286.0409710407257 to execute
# Mining algorithm took 2286.042517185211 to execute
# New_Orleans
# 17274
# Sorting took 0.04021501541137695 to execute
# 0 accounting
# 1 airport
# 2 aquarium
# 3 art_gallery
# 4 atm
# 5 bakery
# 6 bar
# 7 beauty_salon
# 8 bicycle_store
# 9 book_store
# 10 bowling_alley
# 11 bus_station
# 12 cafe
# 13 car_dealer
# 14 car_rental
# 15 car_repair
# 16 car_wash
# 17 casino
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 144.58281803131104 to execute
# Mining algorithm took 144.58402800559998 to execute
# Phoenix
# 54999
# Sorting took 0.07091903686523438 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 1477.376608133316 to execute
# Mining algorithm took 1477.377865076065 to execute
# Raleigh
# 19373
# Sorting took 0.037908077239990234 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 72 zoo
# 167.12091994285583 to execute
# Mining algorithm took 167.12242698669434 to execute
# Indianapolis
# 24214
# Sorting took 0.04335212707519531 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 264.2598340511322 to execute
# Mining algorithm took 264.2611699104309 to execute
# Charlotte
# 26410
# Sorting took 0.04143214225769043 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 cemetery
# 19 city_hall
# 20 clothing_store
# 21 construction_contractor
# 22 convenience_store
# 23 courthouse
# 24 dentist
# 25 department_store
# 26 doctor
# 27 electronics_store
# 28 embassy
# 29 finance
# 30 fire_station
# 31 florist
# 32 funeral_home
# 33 furniture_store
# 34 gas_station
# 35 grocery_or_supermarket
# 36 gym
# 37 hardware_store
# 38 home_goods_store
# 39 hospital
# 40 hotel_and_lodging
# 41 insurance_agency
# 42 jewelry_store
# 43 laundry
# 44 lawyer
# 45 library
# 46 liquor_store
# 47 local_government_office
# 48 locksmith
# 49 movie_theater
# 50 moving_company
# 51 museum
# 52 night_club
# 53 park
# 54 parking
# 55 pet_store
# 56 pharmacy
# 57 physiotherapist
# 58 police
# 59 post_office
# 60 real_estate_agency
# 61 religious_centers
# 62 restaurant
# 63 school
# 64 shoe_store
# 65 spa
# 66 stadium
# 67 storage
# 68 train_station
# 69 travel_agency
# 70 university
# 71 veterinary_care
# 315.5764820575714 to execute
# Mining algorithm took 315.5779299736023 to execute
# Sacramento
# 22987
# Sorting took 0.03895401954650879 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 73 zoo
# 236.0172610282898 to execute
# Mining algorithm took 236.0187051296234 to execute
# St_Louis
# 13610
# Sorting took 0.03275704383850098 to execute
# 0 accounting
# 1 airport
# 2 amusement_park
# 3 aquarium
# 4 art_gallery
# 5 atm
# 6 bakery
# 7 bar
# 8 beauty_salon
# 9 bicycle_store
# 10 book_store
# 11 bowling_alley
# 12 bus_station
# 13 cafe
# 14 car_dealer
# 15 car_rental
# 16 car_repair
# 17 car_wash
# 18 casino
# 19 cemetery
# 20 city_hall
# 21 clothing_store
# 22 construction_contractor
# 23 convenience_store
# 24 courthouse
# 25 dentist
# 26 department_store
# 27 doctor
# 28 electronics_store
# 29 embassy
# 30 finance
# 31 fire_station
# 32 florist
# 33 funeral_home
# 34 furniture_store
# 35 gas_station
# 36 grocery_or_supermarket
# 37 gym
# 38 hardware_store
# 39 home_goods_store
# 40 hospital
# 41 hotel_and_lodging
# 42 insurance_agency
# 43 jewelry_store
# 44 laundry
# 45 lawyer
# 46 library
# 47 liquor_store
# 48 local_government_office
# 49 locksmith
# 50 movie_theater
# 51 moving_company
# 52 museum
# 53 night_club
# 54 park
# 55 parking
# 56 pet_store
# 57 pharmacy
# 58 physiotherapist
# 59 police
# 60 post_office
# 61 real_estate_agency
# 62 religious_centers
# 63 restaurant
# 64 school
# 65 shoe_store
# 66 spa
# 67 stadium
# 68 storage
# 69 train_station
# 70 travel_agency
# 71 university
# 72 veterinary_care
# 84.85438203811646 to execute
# Mining algorithm took 84.85570096969604 to execute

# %%
allResults = []
for city, data in cities.items():
    try:
        city, dataLen, neighborsByAmenity, materTime = mineCityStarPatterns(city)
        amenitiesCounts = defaultdict(lambda: 0)
        for amenity in amenities:
            amenitiesCounts[amenity] = len(data[data.type == amenity])
        
        start = time()
        patterns = {1: [amenity for amenity in amenities]}
        patternsInstances = {}
        patternsPrevs = {1: {amenity:1 for amenity in amenities}}
        
        k = 2
        while len(patterns[k-1]):

            print('Length:', k)
            print('Generating')
            candidates = generateCandidates(patterns[k-1], amenities, patternsPrevs, k-1)
            if not len(candidates):
                break
            print('Candiates: ', len(candidates))
            starInstances = {}
            print('Getting Stars')
            for colocation in tqdm(candidates):
                colocationSplit = colocation.split('.')
                starInstances[colocation] = (colocationSplit, [instance for types, instance in neighborsByAmenity[colocationSplit[0]]
                                                       if checkStar(types, colocationSplit)])

            cliques = {}
            patternsInstances[k] = {}
            patternsPrevs[k] = {}
            print('Checking Stars')
            for colocation, (colocationSplit, instances) in tqdm(starInstances.items()):
                if len(instances):
                    if k == 2:
                        cliqueInstances = genSecondPatterns(colocationSplit, instances)
                        patternPrev = calculcatePatternPrevalence(colocationSplit, cliqueInstances, amenitiesCounts)
                        patternsPrevs[k][colocation] = patternPrev
                        if patternPrev >= th:
                            patternsInstances[k][colocation] = cliqueInstances

                    else:
                        cliqueInstances = genMorePatterns(colocationSplit, instances, patternsInstances)
                        if len(cliqueInstances):
                            patternPrev = calculcatePatternPrevalence(colocationSplit, cliqueInstances, amenitiesCounts)
                            patternsPrevs[k][colocation] = patternPrev
                            if patternPrev >= th:
                                patternsInstances[k][colocation] = cliqueInstances
            patterns[k] = {clique:len(instances) for clique, instances in patternsInstances[k].items()}
            print('Patterns: ', len(patterns[k]))
            print('')
            k += 1
    
        miningTime = time()-start
        print('Mining algorithm took',miningTime , 'to execute')
        allResults.append([city, dataLen, materTime, miningTime, materTime+miningTime, patterns, patternsInstances, patternsPrevs])
        break
    except Exception as e:
        print(e)

# %%
timeResults = [(res[0], res[1], res[3]) for res in allResultsFast]

# %%
with open('Patterns/allResultsFastMater.json','w') as outfile:
    json.dump(timeResults, outfile)

# %%
#Analysis

# %%
len(resultsHuge)
# Out:
# 37

# %%
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode()

# %%
scatter = go.Scatter(
    x = [res[1]/1000.0 for res in resultsHuge],
    y = [res[2] for res in resultsHuge],
    mode = 'markers+text',
    text = [res[0] for res in resultsHuge]
)
layout = go.Layout(
    title='Materialization time',
    hovermode='closest',
    xaxis=dict(
        title='Locations, Thousands',
    ),
    yaxis=dict(
        title='Time, Seconds',
    ),
)
fig = go.Figure(data = [scatter], layout = layout)
iplot(fig)
# Out:
# <div id="033961e5-7eed-4e66-947a-ec6fce0960a9" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("033961e5-7eed-4e66-947a-ec6fce0960a9", [{"type": "scatter", "mode": "markers+text", "text": ["San_Jose", "Birmingham", "Pittsburgh", "Washington", "Milwaukee", "San_Francisco", "Orlando", "Boston", "Portland", "Richmond", "Nashville", "Miami", "Austin", "Cincinnati", "Columbus", "Cleveland", "Detroit", "Lousville", "Memphis", "Oklahoma", "Riverside", "Buffalo", "San_Diego", "Jacksonville", "Baltimore", "Providence", "Chicago", "Las_Vegas", "Dallas", "Philadelphia", "New_Orleans", "Phoenix", "Raleigh", "Indianapolis", "Charlotte", "Sacramento", "St_Louis"], "x": [35.011, 18.703, 17.892, 24.48, 22.798, 19.791, 27.383, 22.979, 36.665, 11.164, 25.389, 20.246, 35.614, 18.352, 33.558, 20.541, 30.249, 25.853, 24.493, 25.5, 9.803, 8.106, 65.261, 27.106, 18.458, 8.104, 65.601, 43.737, 68.366, 46.477, 17.274, 54.999, 19.373, 24.214, 26.41, 22.987, 13.61], "y": [97.30674004554749, 37.33728098869324, 61.98917102813721, 113.27261400222778, 55.38756799697876, 204.99248504638672, 65.90241193771362, 145.76894807815552, 174.08488607406616, 30.8624210357666, 75.48789095878601, 83.93346881866455, 104.4635260105133, 48.10244083404541, 72.25601005554199, 50.01270008087158, 62.98502993583679, 54.89523410797119, 49.70860695838928, 52.0308141708374, 26.514925956726074, 20.34398102760315, 269.6417911052704, 43.054044008255005, 85.42698097229004, 31.82670021057129, 340.353355884552, 111.03325605392456, 170.3950479030609, 226.9371418952942, 62.90603995323181, 124.24688792228699, 39.34567308425903, 48.94856595993042, 56.729904890060425, 67.68804502487183, 24.553786993026733]}], {"title": "Materialization time", "yaxis": {"title": "Time, Seconds"}, "hovermode": "closest", "xaxis": {"title": "Locations, Thousands"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
scatter = go.Scatter(
    x = [res[1]/1000.0 for res in resultsHuge],
    y = [res[3] for res in resultsHuge],
    mode = 'markers+text',
    text = [res[0] for res in resultsHuge]
)
layout = go.Layout(
    title='Mining time',
    hovermode='closest',
    xaxis=dict(
        title='Locations, Thousands',
    ),
    yaxis=dict(
        title='Time, Seconds',
    ),
)
fig = go.Figure(data = [scatter], layout = layout)
iplot(fig)
# Out:
# <div id="6f78ebeb-6b54-4163-8e4a-36a7a61b3568" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6f78ebeb-6b54-4163-8e4a-36a7a61b3568", [{"type": "scatter", "mode": "markers+text", "text": ["San_Jose", "Birmingham", "Pittsburgh", "Washington", "Milwaukee", "San_Francisco", "Orlando", "Boston", "Portland", "Richmond", "Nashville", "Miami", "Austin", "Cincinnati", "Columbus", "Cleveland", "Detroit", "Lousville", "Memphis", "Oklahoma", "Riverside", "Buffalo", "San_Diego", "Jacksonville", "Baltimore", "Providence", "Chicago", "Las_Vegas", "Dallas", "Philadelphia", "New_Orleans", "Phoenix", "Raleigh", "Indianapolis", "Charlotte", "Sacramento", "St_Louis"], "x": [35.011, 18.703, 17.892, 24.48, 22.798, 19.791, 27.383, 22.979, 36.665, 11.164, 25.389, 20.246, 35.614, 18.352, 33.558, 20.541, 30.249, 25.853, 24.493, 25.5, 9.803, 8.106, 65.261, 27.106, 18.458, 8.104, 65.601, 43.737, 68.366, 46.477, 17.274, 54.999, 19.373, 24.214, 26.41, 22.987, 13.61], "y": [8.317876100540161, 1.1488978862762451, 4.749381065368652, 16.98568606376648, 1.3062999248504639, 677.5640988349915, 436.1519410610199, 17.632334232330322, 130.05599188804626, 0.5499699115753174, 2.431101083755493, 14.317347049713135, 32.109368085861206, 1.4723289012908936, 2.3232028484344482, 864.0261559486389, 2.086359977722168, 5.326332092285156, 1.9885690212249756, 2.001944065093994, 2.7405710220336914, 1.0737969875335693, 894.2874310016632, 7.306946039199829, 1.6988508701324463, 0.9290580749511719, 324.56393599510193, 10.963729858398438, 52.20952796936035, 15.604728937149048, 1.1278440952301025, 11.85096001625061, 4.040786027908325, 1.081644058227539, 6.125484943389893, 1.9481399059295654, 0.9118249416351318]}], {"title": "Mining time", "yaxis": {"title": "Time, Seconds"}, "hovermode": "closest", "xaxis": {"title": "Locations, Thousands"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
len(allResultsFast2)
# Out:
# 33

# %%
allResultsFast2 = [res for res in allResultsFast if res[0] in [resst[0] for resst in allResultsNaive]]

# %%
allResultsNaive[10][0]
# Out:
# 'Miami'

# %%
joinRes[10][0]
# Out:
# 'Miami'

# %%
joinRes = [res for res in resultsHuge if res[0] in [resst[0] for resst in allResultsNaive]]

# %%
scatter = go.Scatter(
    x = [res1[1]/1000.0 for res1, res2 in zip(allResultsFast2, joinRes)],
    y = [float(res1[3])/(res1[3]+res2[3]) for res1, res2 in zip(allResultsFast2, joinRes)],
    mode = 'markers',
    text = [res2[0] for res1, res2 in zip(allResultsFast2, joinRes)]
)
layout = go.Layout(
    title='Share of Materialization Time',
    hovermode='closest',
    xaxis=dict(
        title='Locations, Thousands',
    ),
    yaxis=dict(
        title='Time, Seconds',
    ),
)
fig = go.Figure(data = [scatter], layout = layout)
iplot(fig)
# Out:
# <div id="0a0e003f-c275-42cc-9cf9-ea4f8f5ab7a9" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0a0e003f-c275-42cc-9cf9-ea4f8f5ab7a9", [{"type": "scatter", "mode": "markers", "text": ["San_Jose", "Birmingham", "Pittsburgh", "Washington", "Milwaukee", "Orlando", "Boston", "Portland", "Richmond", "Nashville", "Miami", "Austin", "Cincinnati", "Columbus", "Cleveland", "Detroit", "Lousville", "Memphis", "Oklahoma", "Riverside", "Buffalo", "Jacksonville", "Baltimore", "Providence", "Las_Vegas", "Dallas", "New_Orleans", "Phoenix", "Raleigh", "Indianapolis", "Charlotte", "Sacramento", "St_Louis"], "x": [35.011, 18.703, 17.892, 24.48, 22.798, 27.383, 22.979, 36.665, 11.164, 25.389, 20.246, 35.614, 18.352, 33.558, 20.541, 30.249, 25.853, 24.493, 25.5, 9.803, 8.106, 27.106, 18.458, 8.104, 43.737, 68.366, 17.274, 54.999, 19.373, 24.214, 26.41, 22.987, 13.61], "y": [0.5459893217303686, 0.8151822830651495, 0.5522793303834032, 0.34393561620689966, 0.8325107005237821, 0.017080484435367336, 0.36081220652001994, 0.085930006784631, 0.8538889815425292, 0.7494837057538367, 0.32879641619730476, 0.2501044677996546, 0.778014822413152, 0.7914876533678267, 0.00616118257607291, 0.782203189328757, 0.5509744125480028, 0.7531996059674432, 0.7559469454253768, 0.4937963254263991, 0.6722120512442618, 0.47873735992371713, 0.7885853611701151, 0.7484577289135161, 0.5247278980519516, 0.26497949702437923, 0.836301991016426, 0.5571117227116574, 0.5547029129107289, 0.8461761981717703, 0.5332700348494087, 0.7791475737262111, 0.7947486159983946]}], {"title": "Share of Materialization Time", "yaxis": {"title": "Time, Seconds"}, "hovermode": "closest", "xaxis": {"title": "Locations, Thousands"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
patternInstancesPerCity = [cityResult[6] for cityResult in resultsHuge]

# %%
def flattenElements(array):
    return [item for sublist in array for item in sublist]

# %%
patternTypesPerCity = [set(flattenElements([cityResult[k].keys()for k in cityResult.keys()])) for cityResult in patternInstancesPerCity]

# %%
bigger
# Out:
# [['finance.insurance_agency.lawyer.real_estate_agency.travel_agency', 1],
#  ['dentist.finance.insurance_agency.lawyer.real_estate_agency', 1],
#  ['accounting.insurance_agency.lawyer.parking.real_estate_agency', 1],
#  ['accounting.finance.lawyer.real_estate_agency.travel_agency', 1],
#  ['cafe.finance.insurance_agency.lawyer.real_estate_agency', 1],
#  ['accounting.dentist.doctor.finance.lawyer', 1],
#  ['accounting.finance.insurance_agency.lawyer.parking', 1],
#  ['accounting.finance.lawyer.parking.real_estate_agency', 1],
#  ['doctor.finance.insurance_agency.lawyer.real_estate_agency', 2],
#  ['accounting.finance.insurance_agency.lawyer.travel_agency', 1],
#  ['accounting.construction_contractor.finance.lawyer.real_estate_agency', 1],
#  ['city_hall.courthouse.fire_station.local_government_office.police', 1],
#  ['dentist.doctor.finance.insurance_agency.lawyer', 1],
#  ['accounting.finance.insurance_agency.lawyer.real_estate_agency', 12],
#  ['dentist.doctor.finance.lawyer.real_estate_agency', 1],
#  ['finance.insurance_agency.lawyer.parking.real_estate_agency', 1],
#  ['accounting.doctor.finance.lawyer.travel_agency', 1]]

# %%
bigger = []
for pattern, count in Counter(flattenElements(patternTypesPerCity)).items():
    if len(pattern.split('.')) > 4:
        bigger.append([pattern, count])
#         print(pattern, count)
#         break

# %%
13521

# %%
len(set.intersection(*patternTypesPerCity))
# Out:
# 49

# %%
'accounting.insurance_agency.lawyer'

# %%
for pattern in set.intersection(*patternTypesPerCity):
    print(' '.join(pattern.split('.')))
# Out:
# beauty_salon clothing_store
# clothing_store home_goods_store
# construction_contractor restaurant
# beauty_salon real_estate_agency
# finance pharmacy
# insurance_agency lawyer
# dentist lawyer
# accounting dentist
# atm convenience_store
# car_repair construction_contractor
# insurance_agency real_estate_agency
# beauty_salon restaurant
# clothing_store shoe_store
# beauty_salon finance
# accounting doctor
# beauty_salon lawyer
# dentist real_estate_agency
# beauty_salon doctor
# accounting real_estate_agency
# doctor lawyer
# doctor insurance_agency
# clothing_store restaurant
# clothing_store jewelry_store
# doctor restaurant
# construction_contractor lawyer
# construction_contractor finance
# accounting insurance_agency
# accounting restaurant
# atm beauty_salon
# accounting insurance_agency lawyer
# accounting finance
# accounting beauty_salon
# dentist doctor
# finance insurance_agency
# beauty_salon insurance_agency
# finance lawyer
# lawyer real_estate_agency
# finance real_estate_agency
# atm restaurant
# finance restaurant
# atm finance
# accounting lawyer
# doctor finance
# insurance_agency restaurant
# construction_contractor real_estate_agency
# doctor hospital
# doctor real_estate_agency
# construction_contractor doctor
# construction_contractor insurance_agency

# %% [markdown]
# # Recomendation

# %%
city = 'Boston'
patterns = [cityResult[5] for cityResult in resultsHuge if cityResult[0]==city][0]
patternsInstances = [cityResult[6] for cityResult in resultsHuge if cityResult[0]==city][0]
patternsPrevs = [cityResult[7] for cityResult in resultsHuge if cityResult[0]==city][0]
cliques = pd.DataFrame()
instanceId = 0
ids = []

for size, patternss in patternsInstances.items():
    cliquesSize = pd.DataFrame()
    for pattern, instances in tqdm(patternss.items()):
        cliquesPattern = pd.DataFrame()
        for instance in instances:
            instanceId += 1
            clique = cities[city][cities[city].id.isin(instance)]
            ids.extend([instanceId]*len(clique))
            cliquesPattern = cliquesPattern.append(clique)
        cliquesPattern['pattern'] = pattern
        cliquesSize = cliquesSize.append(cliquesPattern)
    cliquesSize['size'] = size
    cliques = cliques.append(cliquesSize)

cliques['instanceId'] = ids
# Out:
# 100%|██████████| 227/227 [03:54<00:00,  1.07s/it]
# 100%|██████████| 22/22 [01:25<00:00,  6.50s/it]
# 100%|██████████| 516/516 [02:39<00:00,  1.70it/s]

# %%
def getPotentialPatterns(amenity, patterns, patternsPrevs):
    possiblePatterns = {}
    for size, patternTypes in patterns.items():
        if int(size) > 2:
            possiblePatterns.update({'.'.join(pattern.split('.')[1:]): patternsPrevs[size][pattern]
                                     for pattern in patternTypes if pattern.startswith(amenity)})
    return possiblePatterns

def scorePotentialPattens(potentialPatterns, clusterCliques):
    potentialPatternsInCluster = pd.DataFrame()
    scores = []
    for pattern, prevalence in potentialPatterns.items():
        print(pattern)
        patternsInCluster = clusterCliques.loc[clusterCliques.pattern == pattern]
        patternsCount = len(patternsInCluster.groupby('instanceId'))
        if patternsCount:
            scores.extend([prevalence/patternsCount]*len(patternsInCluster))
            potentialPatternsInCluster = potentialPatternsInCluster.append(patternsInCluster)
    potentialPatternsInCluster['score'] = scores
    return potentialPatternsInCluster

# %%
amenity = 'cafe'
clusterId = 67
clusterCliques = cliques[cliques.clusterId == clusterId]
potentialPatterns = getPotentialPatterns(amenity, patterns, patternsPrevs)
potentialPatternsInCluster = scorePotentialPattens(potentialPatterns, clusterCliques).sort_values(by='score', ascending=False)
# Out:
# clothing_store.lawyer
# finance.insurance_agency.lawyer
# finance.lawyer.real_estate_agency
# clothing_store.finance
# insurance_agency.lawyer
# dentist.lawyer
# finance.lawyer
# insurance_agency.real_estate_agency
# finance.real_estate_agency
# finance.restaurant
# real_estate_agency.restaurant
# dentist.insurance_agency
# lawyer.real_estate_agency
# dentist.finance
# clothing_store.restaurant
# doctor.restaurant
# clothing_store.jewelry_store
# finance.insurance_agency

# %%
potentialPatterns
# Out:
# {'clothing_store.finance': 0.0811930405965203,
#  'clothing_store.jewelry_store': 0.05508474576271186,
#  'clothing_store.lawyer': 0.0614406779661017,
#  'clothing_store.restaurant': 0.05235350624399616,
#  'dentist.finance': 0.06213753106876554,
#  'dentist.insurance_agency': 0.057203389830508475,
#  'dentist.lawyer': 0.0614406779661017,
#  'doctor.restaurant': 0.056074766355140186,
#  'finance.insurance_agency': 0.09533898305084745,
#  'finance.insurance_agency.lawyer': 0.07203389830508475,
#  'finance.lawyer': 0.1440677966101695,
#  'finance.lawyer.real_estate_agency': 0.06519453207150368,
#  'finance.real_estate_agency': 0.11251314405888538,
#  'finance.restaurant': 0.0893371757925072,
#  'insurance_agency.lawyer': 0.1059322033898305,
#  'insurance_agency.real_estate_agency': 0.058885383806519455,
#  'lawyer.real_estate_agency': 0.08096740273396424,
#  'real_estate_agency.restaurant': 0.074447646493756}

# %%
potentialPatternsInCluster.to_csv('Patterns/BostonPotentialBar.csv',index=None)

# %%
patternsInCluster = cliques.loc[cliques.pattern == 'cafe.clothing_store.finance']
patternsCount = len(patternsInCluster.groupby('instanceId'))

# %%
len(cliques.groupby('instanceId'))
# Out:
# 258138

# %%
cliques.to_csv('Patterns/BostonAllCliques.csv', index = None)

# %%
patternsPrevs['3']['cafe.clothing_store.finance']
# Out:
# 0.0811930405965203

# %%
potentialPatternsInCluster[8:11]
# Out:
#         latitude  longitude                type  clusterId     id  \
# 9941   42.364275 -71.102047      clothing_store         67   9941
# 9940   42.364143 -71.101981             finance         67   9940
# 10027  42.366111 -71.104610  real_estate_agency         67  10027
#
#                           pattern size  instanceId     score
# 9941       clothing_store.finance    2      216068  0.027064
# 9940       clothing_store.finance    2      216068  0.027064
# 10027  finance.real_estate_agency    2      209011  0.014064

# %%
[cityResult[0] for cityResult in resultsHuge if cityResult[0]==city][0]
# Out:
# 'Boston'

# %%
len(resultsHuge)
# Out:
# 37

# %%
cities['Boston']
# Out:
#         latitude  longitude                     type  clusterId     id
# 0      42.385209 -70.973779       real_estate_agency          0      0
# 1      42.385158 -70.974066                   doctor          0      1
# 2      42.385296 -70.974064                   doctor          0      2
# 3      42.385098 -70.973105                   school          0      3
# 4      42.385177 -70.973779                   school          0      4
# 5      42.384497 -70.973842       real_estate_agency          0      5
# 6      42.384521 -70.973152              bus_station          0      6
# 7      42.386828 -70.975855       real_estate_agency          0      7
# 8      42.386828 -70.975853       real_estate_agency          0      8
# 9      42.387088 -70.976300           moving_company          0      9
# 10     42.397453 -70.991664                   bakery          3     10
# 11     42.397133 -70.991081         insurance_agency          3     11
# 12     42.397114 -70.991510             liquor_store          3     12
# 13     42.397876 -70.991657   grocery_or_supermarket          3     13
# 14     42.385700 -70.974517             beauty_salon          0     14
# 15     42.385739 -70.974561                   doctor          0     15
# 16     42.385636 -70.974571                   doctor          0     16
# 18     42.385674 -70.974886                  laundry          0     18
# 19     42.385723 -70.974964             beauty_salon          0     19
# 20     42.385671 -70.974618  construction_contractor          0     20
# 21     42.385420 -70.974292             beauty_salon          0     21
# 22     42.385647 -70.974753                      gym          0     22
# 23     42.386154 -70.975497                   doctor          0     23
# 24     42.386147 -70.975508                   doctor          0     24
# 28     42.386147 -70.975507               restaurant          0     28
# 29     42.386108 -70.975366             beauty_salon          0     29
# 30     42.385815 -70.975187               restaurant          0     30
# 31     42.385990 -70.975289                      atm          0     31
# 32     42.385990 -70.975289             liquor_store          0     32
# 33     42.385922 -70.975294                     cafe          0     33
# ...          ...        ...                      ...        ...    ...
# 26200  42.396666 -71.048450                     cafe          8  26200
# 26201  42.396821 -71.048417               restaurant          8  26201
# 26202  42.396609 -71.051536   grocery_or_supermarket          8  26202
# 26203  42.396775 -71.051580   grocery_or_supermarket          8  26203
# 26204  42.396362 -71.052397               restaurant          8  26204
# 26205  42.395796 -71.052504                     cafe          8  26205
# 26206  42.261855 -71.094016                   doctor        133  26206
# 26207  42.261867 -71.093877                   doctor        133  26207
# 26208  42.261515 -71.092933                   doctor        133  26208
# 26209  42.261523 -71.092924        religious_centers        133  26209
# 26210  42.260947 -71.093195        religious_centers        133  26210
# 26211  42.260947 -71.093197                   school        133  26211
# 26212  42.260487 -71.093956                   doctor        133  26212
# 26213  42.260335 -71.094371                   doctor        133  26213
# 26214  42.260810 -71.094749                   school        133  26214
# 26215  42.355963 -71.112407                   school         70  26215
# 26216  42.382899 -71.039660              gas_station         11  26216
# 26217  42.382911 -71.039652                     cafe         11  26217
# 26218  42.382958 -71.039678               car_repair         11  26218
# 26219  42.384142 -70.984212  construction_contractor          0  26219
# 26220  42.384198 -70.984430                      gym          0  26220
# 26221  42.384198 -70.984430                   doctor          0  26221
# 26222  42.384198 -70.984430  construction_contractor          0  26222
# 26223  42.384198 -70.984430          physiotherapist          0  26223
# 26224  42.384198 -70.984430               car_repair          0  26224
# 26225  42.353928 -71.105367               restaurant         67  26225
# 26226  42.353894 -71.105398                   doctor         67  26226
# 26227  42.353903 -71.105453        hotel_and_lodging         67  26227
# 26228  42.353906 -71.105302               restaurant         67  26228
# 26229  42.395684 -71.109062                  finance         57  26229
#
# [22979 rows x 5 columns]
